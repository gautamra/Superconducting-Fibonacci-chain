# %%
from Core_lib import *

# %%
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 14}

mpl.rc('font', **font)
mpl.rcParams['figure.figsize'] = 6,3.6
mpl.rcParams['figure.facecolor'] = "w"
mpl.rcParams.update({'figure.autolayout': True})

# %%
def Merge(dict1, dict2):
    return(dict2.update(dict1))

# %% [markdown]
# ## u_0 vs V phase diagram

# %%
comp_u0V = pickle.load(open("comp_u0V.p","rb"))
comp_u0VChris = pickle.load(open("comp_u0VChris.p","rb"))
compu_u0V = Merge(comp_u0V,comp_u0VChris)
keys = sorted(comp_u0V.keys())
[print(key) for key in keys]
# Out:
# (0.74, 0)
# (0.74, 2)
# (0.74, 4)
# (0.74, 6)
# (0.74, 8)
# (0.74, 10)
# (0.74, 12)
# (0.74, 14)
# (0.74, 16)
# (0.74, 18)
# (0.74, 20)
# (0.74, 22)
# (0.74, 24)
# (0.74, 26)
# (0.74, 28)
# (0.74, 30)
# (0.74, 32)
# (0.74, 34)
# (0.74, 36)
# (0.74, 38)
# (0.74, 40)
# (0.74, 42)
# (0.74, 44)
# (0.74, 46)
# (0.74, 48)
# (0.74, 50)
# (0.74, 52)
# (0.74, 54)
# (0.74, 56)
# (0.74, 58)
# (0.74, 60)
# (0.74, 62)
# (0.74, 64)
# (0.74, 66)
# (0.74, 68)
# (0.74, 70)
# (0.74, 72)
# (0.74, 74)
# (0.74, 76)
# (0.74, 78)
# (0.74, 80)
# (0.74, 82)
# (0.74, 84)
# (0.74, 86)
# (0.74, 88)
# (0.74, 90)
# (0.74, 92)
# (0.74, 94)
# (0.74, 96)
# (0.74, 98)
# (0.74, 100)
# (0.74, 102)
# (0.74, 104)
# (0.74, 106)
# (0.74, 108)
# (0.74, 110)
# (0.74, 112)
# (0.74, 114)
# (0.76, 0)
# (0.76, 2)
# (0.76, 4)
# (0.76, 6)
# (0.76, 8)
# (0.76, 10)
# (0.76, 12)
# (0.76, 14)
# (0.76, 16)
# (0.76, 18)
# (0.76, 20)
# (0.76, 22)
# (0.76, 24)
# (0.76, 26)
# (0.76, 28)
# (0.76, 30)
# (0.76, 32)
# (0.76, 34)
# (0.76, 36)
# (0.76, 38)
# (0.76, 40)
# (0.76, 42)
# (0.76, 44)
# (0.76, 46)
# (0.76, 48)
# (0.76, 50)
# (0.76, 52)
# (0.76, 54)
# (0.76, 56)
# (0.76, 58)
# (0.76, 60)
# (0.76, 62)
# (0.76, 64)
# (0.76, 66)
# (0.76, 68)
# (0.76, 70)
# (0.76, 72)
# (0.76, 74)
# (0.76, 76)
# (0.76, 78)
# (0.76, 80)
# (0.76, 82)
# (0.76, 84)
# (0.76, 86)
# (0.76, 88)
# (0.76, 90)
# (0.76, 92)
# (0.76, 94)
# (0.76, 96)
# (0.76, 98)
# (0.76, 100)
# (0.76, 102)
# (0.76, 104)
# (0.76, 106)
# (0.76, 108)
# (0.76, 110)
# (0.76, 112)
# (0.76, 114)
# (0.78, 0)
# (0.78, 2)
# (0.78, 4)
# (0.78, 6)
# (0.78, 8)
# (0.78, 10)
# (0.78, 12)
# (0.78, 14)
# (0.78, 16)
# (0.78, 18)
# (0.78, 20)
# (0.78, 22)
# (0.78, 24)
# (0.78, 26)
# (0.78, 28)
# (0.78, 30)
# (0.78, 32)
# (0.78, 34)
# (0.78, 36)
# (0.78, 38)
# (0.78, 40)
# (0.78, 42)
# (0.78, 44)
# (0.78, 46)
# (0.78, 48)
# (0.78, 50)
# (0.78, 52)
# (0.78, 54)
# (0.78, 56)
# (0.78, 58)
# (0.78, 60)
# (0.78, 62)
# (0.78, 64)
# (0.78, 66)
# (0.78, 68)
# (0.78, 70)
# (0.78, 72)
# (0.78, 74)
# (0.78, 76)
# (0.78, 78)
# (0.78, 80)
# (0.78, 82)
# (0.78, 84)
# (0.78, 86)
# (0.78, 88)
# (0.78, 90)
# (0.78, 92)
# (0.78, 94)
# (0.78, 96)
# (0.78, 98)
# (0.78, 100)
# (0.78, 102)
# (0.78, 104)
# (0.78, 106)
# (0.78, 108)
# (0.78, 110)
# (0.78, 112)
# (0.78, 114)
# (0.8, 0)
# (0.8, 2)
# (0.8, 4)
# (0.8, 6)
# (0.8, 8)
# (0.8, 10)
# (0.8, 12)
# (0.8, 14)
# (0.8, 16)
# (0.8, 18)
# (0.8, 20)
# (0.8, 22)
# (0.8, 24)
# (0.8, 26)
# (0.8, 28)
# (0.8, 30)
# (0.8, 32)
# (0.8, 34)
# (0.8, 36)
# (0.8, 38)
# (0.8, 40)
# (0.8, 42)
# (0.8, 44)
# (0.8, 46)
# (0.8, 48)
# (0.8, 50)
# (0.8, 52)
# (0.8, 54)
# (0.8, 56)
# (0.8, 58)
# (0.8, 60)
# (0.8, 62)
# (0.8, 64)
# (0.8, 66)
# (0.8, 68)
# (0.8, 70)
# (0.8, 72)
# (0.8, 74)
# (0.8, 76)
# (0.8, 78)
# (0.8, 80)
# (0.8, 82)
# (0.8, 84)
# (0.8, 86)
# (0.8, 88)
# (0.8, 90)
# (0.8, 92)
# (0.8, 94)
# (0.8, 96)
# (0.8, 98)
# (0.8, 100)
# (0.8, 102)
# (0.8, 104)
# (0.8, 106)
# (0.8, 108)
# (0.8, 110)
# (0.8, 112)
# (0.8, 114)
# (0.81, 0)
# (0.81, 2)
# (0.81, 4)
# (0.81, 6)
# (0.81, 8)
# (0.81, 10)
# (0.81, 12)
# (0.81, 14)
# (0.81, 16)
# (0.81, 18)
# (0.81, 20)
# (0.81, 22)
# (0.81, 24)
# (0.81, 26)
# (0.81, 28)
# (0.81, 30)
# (0.81, 32)
# (0.81, 34)
# (0.81, 36)
# (0.81, 38)
# (0.81, 40)
# (0.81, 42)
# (0.81, 44)
# (0.81, 46)
# (0.81, 48)
# (0.81, 50)
# (0.81, 52)
# (0.81, 54)
# (0.81, 56)
# (0.81, 58)
# (0.81, 60)
# (0.81, 62)
# (0.81, 64)
# (0.81, 66)
# (0.81, 68)
# (0.81, 70)
# (0.81, 72)
# (0.81, 74)
# (0.81, 76)
# (0.81, 78)
# (0.81, 80)
# (0.81, 82)
# (0.81, 84)
# (0.81, 86)
# (0.81, 88)
# (0.81, 90)
# (0.81, 92)
# (0.81, 94)
# (0.81, 96)
# (0.81, 98)
# (0.81, 100)
# (0.81, 102)
# (0.81, 104)
# (0.81, 106)
# (0.81, 108)
# (0.81, 110)
# (0.81, 112)
# (0.81, 114)
# (0.82, 0)
# (0.82, 2)
# (0.82, 4)
# (0.82, 6)
# (0.82, 8)
# (0.82, 10)
# (0.82, 12)
# (0.82, 14)
# (0.82, 16)
# (0.82, 18)
# (0.82, 20)
# (0.82, 22)
# (0.82, 24)
# (0.82, 26)
# (0.82, 28)
# (0.82, 30)
# (0.82, 32)
# (0.82, 34)
# (0.82, 36)
# (0.82, 38)
# (0.82, 40)
# (0.82, 42)
# (0.82, 44)
# (0.82, 46)
# (0.82, 48)
# (0.82, 50)
# (0.82, 52)
# (0.82, 54)
# (0.82, 56)
# (0.82, 58)
# (0.82, 60)
# (0.82, 62)
# (0.82, 64)
# (0.82, 66)
# (0.82, 68)
# (0.82, 70)
# (0.82, 72)
# (0.82, 74)
# (0.82, 76)
# (0.82, 78)
# (0.82, 80)
# (0.82, 82)
# (0.82, 84)
# (0.82, 86)
# (0.82, 88)
# (0.82, 90)
# (0.82, 92)
# (0.82, 94)
# (0.82, 96)
# (0.82, 98)
# (0.82, 100)
# (0.82, 102)
# (0.82, 104)
# (0.82, 106)
# (0.82, 108)
# (0.82, 110)
# (0.82, 112)
# (0.82, 114)
# (0.84, 0)
# (0.84, 2)
# (0.84, 4)
# (0.84, 6)
# (0.84, 8)
# (0.84, 10)
# (0.84, 12)
# (0.84, 14)
# (0.84, 16)
# (0.84, 18)
# (0.84, 20)
# (0.84, 22)
# (0.84, 24)
# (0.84, 26)
# (0.84, 28)
# (0.84, 30)
# (0.84, 32)
# (0.84, 34)
# (0.84, 36)
# (0.84, 38)
# (0.84, 40)
# (0.84, 42)
# (0.84, 44)
# (0.84, 46)
# (0.84, 48)
# (0.84, 50)
# (0.84, 52)
# (0.84, 54)
# (0.84, 56)
# (0.84, 58)
# (0.84, 60)
# (0.84, 62)
# (0.84, 64)
# (0.84, 66)
# (0.84, 68)
# (0.84, 70)
# (0.84, 72)
# (0.84, 74)
# (0.84, 76)
# (0.84, 78)
# (0.84, 80)
# (0.84, 82)
# (0.84, 84)
# (0.84, 86)
# (0.84, 88)
# (0.84, 90)
# (0.84, 92)
# (0.84, 94)
# (0.84, 96)
# (0.84, 98)
# (0.84, 100)
# (0.84, 102)
# (0.84, 104)
# (0.84, 106)
# (0.84, 108)
# (0.84, 110)
# (0.84, 112)
# (0.84, 114)
# (0.85, 0)
# (0.85, 2)
# (0.85, 4)
# (0.85, 6)
# (0.85, 8)
# (0.85, 10)
# (0.85, 12)
# (0.85, 14)
# (0.85, 16)
# (0.85, 18)
# (0.85, 20)
# (0.85, 22)
# (0.85, 24)
# (0.85, 26)
# (0.85, 28)
# (0.85, 30)
# (0.85, 32)
# (0.85, 34)
# (0.85, 36)
# (0.85, 38)
# (0.85, 40)
# (0.85, 42)
# (0.85, 44)
# (0.85, 46)
# (0.85, 48)
# (0.85, 50)
# (0.85, 52)
# (0.85, 54)
# (0.85, 56)
# (0.85, 58)
# (0.85, 60)
# (0.85, 62)
# (0.85, 64)
# (0.85, 66)
# (0.85, 68)
# (0.85, 70)
# (0.85, 72)
# (0.85, 74)
# (0.85, 76)
# (0.85, 78)
# (0.85, 80)
# (0.85, 82)
# (0.85, 84)
# (0.85, 86)
# (0.85, 88)
# (0.85, 90)
# (0.85, 92)
# (0.85, 94)
# (0.85, 96)
# (0.85, 98)
# (0.85, 100)
# (0.85, 102)
# (0.85, 104)
# (0.85, 106)
# (0.85, 108)
# (0.85, 110)
# (0.85, 112)
# (0.85, 114)
# (0.86, 0)
# (0.86, 2)
# (0.86, 4)
# (0.86, 6)
# (0.86, 8)
# (0.86, 10)
# (0.86, 12)
# (0.86, 14)
# (0.86, 16)
# (0.86, 18)
# (0.86, 20)
# (0.86, 22)
# (0.86, 24)
# (0.86, 26)
# (0.86, 28)
# (0.86, 30)
# (0.86, 32)
# (0.86, 34)
# (0.86, 36)
# (0.86, 38)
# (0.86, 40)
# (0.86, 42)
# (0.86, 44)
# (0.86, 46)
# (0.86, 48)
# (0.86, 50)
# (0.86, 52)
# (0.86, 54)
# (0.86, 56)
# (0.86, 58)
# (0.86, 60)
# (0.86, 62)
# (0.86, 64)
# (0.86, 66)
# (0.86, 68)
# (0.86, 70)
# (0.86, 72)
# (0.86, 74)
# (0.86, 76)
# (0.86, 78)
# (0.86, 80)
# (0.86, 82)
# (0.86, 84)
# (0.86, 86)
# (0.86, 88)
# (0.86, 90)
# (0.86, 92)
# (0.86, 94)
# (0.86, 96)
# (0.86, 98)
# (0.86, 100)
# (0.86, 102)
# (0.86, 104)
# (0.86, 106)
# (0.86, 108)
# (0.86, 110)
# (0.86, 112)
# (0.86, 114)
# (0.88, 0)
# (0.88, 2)
# (0.88, 4)
# (0.88, 6)
# (0.88, 8)
# (0.88, 10)
# (0.88, 12)
# (0.88, 14)
# (0.88, 16)
# (0.88, 18)
# (0.88, 20)
# (0.88, 22)
# (0.88, 24)
# (0.88, 26)
# (0.88, 28)
# (0.88, 30)
# (0.88, 32)
# (0.88, 34)
# (0.88, 36)
# (0.88, 38)
# (0.88, 40)
# (0.88, 42)
# (0.88, 44)
# (0.88, 46)
# (0.88, 48)
# (0.88, 50)
# (0.88, 52)
# (0.88, 54)
# (0.88, 56)
# (0.88, 58)
# (0.88, 60)
# (0.88, 62)
# (0.88, 64)
# (0.88, 66)
# (0.88, 68)
# (0.88, 70)
# (0.88, 72)
# (0.88, 74)
# (0.88, 76)
# (0.88, 78)
# (0.88, 80)
# (0.88, 82)
# (0.88, 84)
# (0.88, 86)
# (0.88, 88)
# (0.88, 90)
# (0.88, 92)
# (0.88, 94)
# (0.88, 96)
# (0.88, 98)
# (0.88, 100)
# (0.88, 102)
# (0.88, 104)
# (0.88, 106)
# (0.88, 108)
# (0.88, 110)
# (0.88, 112)
# (0.88, 114)
# (0.9, 0)
# (0.9, 2)
# (0.9, 4)
# (0.9, 6)
# (0.9, 8)
# (0.9, 10)
# (0.9, 12)
# (0.9, 14)
# (0.9, 16)
# (0.9, 18)
# (0.9, 20)
# (0.9, 22)
# (0.9, 24)
# (0.9, 26)
# (0.9, 28)
# (0.9, 30)
# (0.9, 32)
# (0.9, 34)
# (0.9, 36)
# (0.9, 38)
# (0.9, 40)
# (0.9, 42)
# (0.9, 44)
# (0.9, 46)
# (0.9, 48)
# (0.9, 50)
# (0.9, 52)
# (0.9, 54)
# (0.9, 56)
# (0.9, 58)
# (0.9, 60)
# (0.9, 62)
# (0.9, 64)
# (0.9, 66)
# (0.9, 68)
# (0.9, 70)
# (0.9, 72)
# (0.9, 74)
# (0.9, 76)
# (0.9, 78)
# (0.9, 80)
# (0.9, 82)
# (0.9, 84)
# (0.9, 86)
# (0.9, 88)
# (0.9, 90)
# (0.9, 92)
# (0.9, 94)
# (0.9, 96)
# (0.9, 98)
# (0.9, 100)
# (0.9, 102)
# (0.9, 104)
# (0.9, 106)
# (0.9, 108)
# (0.9, 110)
# (0.9, 112)
# (0.9, 114)
# (0.92, 0)
# (0.92, 2)
# (0.92, 4)
# (0.92, 6)
# (0.92, 8)
# (0.92, 10)
# (0.92, 12)
# (0.92, 14)
# (0.92, 16)
# (0.92, 18)
# (0.92, 20)
# (0.92, 22)
# (0.92, 24)
# (0.92, 26)
# (0.92, 28)
# (0.92, 30)
# (0.92, 32)
# (0.92, 34)
# (0.92, 36)
# (0.92, 38)
# (0.92, 40)
# (0.92, 42)
# (0.92, 44)
# (0.92, 46)
# (0.92, 48)
# (0.92, 50)
# (0.92, 52)
# (0.92, 54)
# (0.92, 56)
# (0.92, 58)
# (0.92, 60)
# (0.92, 62)
# (0.92, 64)
# (0.92, 66)
# (0.92, 68)
# (0.92, 70)
# (0.92, 72)
# (0.92, 74)
# (0.92, 76)
# (0.92, 78)
# (0.92, 80)
# (0.92, 82)
# (0.92, 84)
# (0.92, 86)
# (0.92, 88)
# (0.92, 90)
# (0.92, 92)
# (0.92, 94)
# (0.92, 96)
# (0.92, 98)
# (0.92, 100)
# (0.92, 102)
# (0.92, 104)
# (0.92, 106)
# (0.92, 108)
# (0.92, 110)
# (0.92, 112)
# (0.92, 114)
# (0.95, 0)
# (0.95, 2)
# (0.95, 4)
# (0.95, 6)
# (0.95, 8)
# (0.95, 10)
# (0.95, 12)
# (0.95, 14)
# (0.95, 16)
# (0.95, 18)
# (0.95, 20)
# (0.95, 22)
# (0.95, 24)
# (0.95, 26)
# (0.95, 28)
# (0.95, 30)
# (0.95, 32)
# (0.95, 34)
# (0.95, 36)
# (0.95, 38)
# (0.95, 40)
# (0.95, 42)
# (0.95, 44)
# (0.95, 46)
# (0.95, 48)
# (0.95, 50)
# (0.95, 52)
# (0.95, 54)
# (0.95, 56)
# (0.95, 58)
# (0.95, 60)
# (0.95, 62)
# (0.95, 64)
# (0.95, 66)
# (0.95, 68)
# (0.95, 70)
# (0.95, 72)
# (0.95, 74)
# (0.95, 76)
# (0.95, 78)
# (0.95, 80)
# (0.95, 82)
# (0.95, 84)
# (0.95, 86)
# (0.95, 88)
# (0.95, 90)
# (0.95, 92)
# (0.95, 94)
# (0.95, 96)
# (0.95, 98)
# (0.95, 100)
# (0.95, 102)
# (0.95, 104)
# (0.95, 106)
# (0.95, 108)
# (0.95, 110)
# (0.95, 112)
# (0.95, 114)
# (1.0, 0)
# (1.0, 2)
# (1.0, 4)
# (1.0, 6)
# (1.0, 8)
# (1.0, 10)
# (1.0, 12)
# (1.0, 14)
# (1.0, 16)
# (1.0, 18)
# (1.0, 20)
# (1.0, 22)
# (1.0, 24)
# (1.0, 26)
# (1.0, 28)
# (1.0, 30)
# (1.0, 32)
# (1.0, 34)
# (1.0, 36)
# (1.0, 38)
# (1.0, 40)
# (1.0, 42)
# (1.0, 44)
# (1.0, 46)
# (1.0, 48)
# (1.0, 50)
# (1.0, 52)
# (1.0, 54)
# (1.0, 56)
# (1.0, 58)
# (1.0, 60)
# (1.0, 62)
# (1.0, 64)
# (1.0, 66)
# (1.0, 68)
# (1.0, 70)
# (1.0, 72)
# (1.0, 74)
# (1.0, 76)
# (1.0, 78)
# (1.0, 80)
# (1.0, 82)
# (1.0, 84)
# (1.0, 86)
# (1.0, 88)
# (1.0, 90)
# (1.0, 92)
# (1.0, 94)
# (1.0, 96)
# (1.0, 98)
# (1.0, 100)
# (1.0, 102)
# (1.0, 104)
# (1.0, 106)
# (1.0, 108)
# (1.0, 110)
# (1.0, 112)
# (1.0, 114)
# (1.05, 0)
# (1.05, 2)
# (1.05, 4)
# (1.05, 6)
# (1.05, 8)
# (1.05, 10)
# (1.05, 12)
# (1.05, 14)
# (1.05, 16)
# (1.05, 18)
# (1.05, 20)
# (1.05, 22)
# (1.05, 24)
# (1.05, 26)
# (1.05, 28)
# (1.05, 30)
# (1.05, 32)
# (1.05, 34)
# (1.05, 36)
# (1.05, 38)
# (1.05, 40)
# (1.05, 42)
# (1.05, 44)
# (1.05, 46)
# (1.05, 48)
# (1.05, 50)
# (1.05, 52)
# (1.05, 54)
# (1.05, 56)
# (1.05, 58)
# (1.05, 60)
# (1.05, 62)
# (1.05, 64)
# (1.05, 66)
# (1.05, 68)
# (1.05, 70)
# (1.05, 72)
# (1.05, 74)
# (1.05, 76)
# (1.05, 78)
# (1.05, 80)
# (1.05, 82)
# (1.05, 84)
# (1.05, 86)
# (1.05, 88)
# (1.05, 90)
# (1.05, 92)
# (1.05, 94)
# (1.05, 96)
# (1.05, 98)
# (1.05, 100)
# (1.05, 102)
# (1.05, 104)
# (1.05, 106)
# (1.05, 108)
# (1.05, 110)
# (1.05, 112)
# (1.05, 114)
# (1.1, 0)
# (1.1, 2)
# (1.1, 4)
# (1.1, 6)
# (1.1, 8)
# (1.1, 10)
# (1.1, 12)
# (1.1, 14)
# (1.1, 16)
# (1.1, 18)
# (1.1, 20)
# (1.1, 22)
# (1.1, 24)
# (1.1, 26)
# (1.1, 28)
# (1.1, 30)
# (1.1, 32)
# (1.1, 34)
# (1.1, 36)
# (1.1, 38)
# (1.1, 40)
# (1.1, 42)
# (1.1, 44)
# (1.1, 46)
# (1.1, 48)
# (1.1, 50)
# (1.1, 52)
# (1.1, 54)
# (1.1, 56)
# (1.1, 58)
# (1.1, 60)
# (1.1, 62)
# (1.1, 64)
# (1.1, 66)
# (1.1, 68)
# (1.1, 70)
# (1.1, 72)
# (1.1, 74)
# (1.1, 76)
# (1.1, 78)
# (1.1, 80)
# (1.1, 82)
# (1.1, 84)
# (1.1, 86)
# (1.1, 88)
# (1.1, 90)
# (1.1, 92)
# (1.1, 94)
# (1.1, 96)
# (1.1, 98)
# (1.1, 100)
# (1.1, 102)
# (1.1, 104)
# (1.1, 106)
# (1.1, 108)
# (1.1, 110)
# (1.1, 112)
# (1.1, 114)
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
Vs = []
u0_inds = []
for key in keys:
    V,u0_ind = key
    if V not in Vs:
        Vs.append(V)
    if u0_ind not in u0_inds:
        u0_inds.append(u0_ind)
u0s = [u0_ind/100 for u0_ind in u0_inds]

# Vs = Vs[1:]

# %%
DeltaAvgArray = []
for u0_ind in u0_inds:
    DeltaAvgList = []
    for V in Vs:
        DeltaAvg = np.average(comp_u0V[(V,u0_ind)]["Delta"])
        DeltaAvgList.append(DeltaAvg.real)
    DeltaAvgArray.append(DeltaAvgList)

# %%
fig, ax = plt.subplots()

ax.contourf(Vs, u0s ,DeltaAvgArray)

# %%
fig, ax = plt.subplots()

ax.imshow(DeltaAvgArray, origin = 'lower', extent = (min(Vs),max(Vs),min(u0s),max(u0s)))

# %%
u0s = np.array(u0s)
u0lines = (u0s[:-1]+u0s[1:])/2
u0lines = np.hstack((u0lines[0]-(u0lines[1]-u0lines[0]),u0lines, 2*u0lines[len(u0lines)-1] - u0lines[len(u0lines)-2]))
u0lines
# Out:
# array([-0.01,  0.01,  0.03,  0.05,  0.07,  0.09,  0.11,  0.13,  0.15,
#         0.17,  0.19,  0.21,  0.23,  0.25,  0.27,  0.29,  0.31,  0.33,
#         0.35,  0.37,  0.39,  0.41,  0.43,  0.45,  0.47,  0.49,  0.51,
#         0.53,  0.55,  0.57,  0.59,  0.61,  0.63,  0.65,  0.67,  0.69,
#         0.71,  0.73,  0.75,  0.77,  0.79,  0.81,  0.83,  0.85,  0.87,
#         0.89,  0.91,  0.93,  0.95,  0.97,  0.99,  1.01,  1.03,  1.05,
#         1.07,  1.09,  1.11,  1.13,  1.15])

# %%
Vs = np.array(Vs)
Vlines = (Vs[:-1]+Vs[1:])/2
Vlines = np.hstack((Vlines[0]-(Vlines[1]-Vlines[0]),Vlines, 2*Vlines[len(Vlines)-1] - Vlines[len(Vlines)-2]))
Vlines
# Out:
# array([0.73 , 0.75 , 0.77 , 0.79 , 0.805, 0.815, 0.83 , 0.845, 0.855,
#        0.87 , 0.89 , 0.91 , 0.935, 0.975, 1.025, 1.075, 1.125])

# %%
fig, axes = plt.subplots(1,2,gridspec_kw={'width_ratios':[16,1]})
ax, axcb = axes

cmap = mpl.cm.get_cmap('viridis')
Deltamax = max(max(DeltaAvgArray))

ax.set_xlim((Vlines[0],Vlines[-1]))
ax.set_ylim((u0lines[0],u0lines[-1]))
ax.set_xlabel("$V$")
ax.set_ylabel("$u_0$")

for iu0 in range(len(u0s)):
    for iv in range(len(Vs[:])):
        color = cmap(DeltaAvgArray[iu0][iv]/Deltamax)
        rect = plt.Rectangle((Vlines[iv], u0lines[iu0]), Vlines[iv+1]-Vlines[iv], u0lines[iu0+1]-u0lines[iu0],
                     facecolor=color)
        ax.add_patch(rect) 

# fig, ax = plt.subplots(figsize=(6, 1))
# fig.subplots_adjust(bottom=0.5)


norm = mpl.colors.Normalize(vmin=0, vmax=Deltamax)
cb1 = mpl.colorbar.ColorbarBase(axcb, cmap=cmap,
                                norm=norm,
                                orientation='vertical')
cb1.set_label('$\\Delta_{avg}$')

# %%
Vs
# Out:
# array([0.74, 0.76, 0.78, 0.8 , 0.81, 0.82, 0.84, 0.85, 0.86, 0.88, 0.9 ,
#        0.92, 0.95, 1.  , 1.05, 1.1 ])
